# %% [markdown]
# # **Import all the necessary files**
# *  I would also like to mention that i have found the dataset is wrong as total samples collected - Positive should provide us the Negative but it was wrong so, i dropped the Negative from the DF
#
# **1.  I would like to say i am not so expert in it but i tried on my own please review my code and give feedback******

# %%
import matplotlib as plt
import sklearn as ski
import pandas as pd
import numpy as np
import seaborn as sea

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

pd.options.display.max_rows = None

df = pd.read_excel("../input/statewisetestingdetails/StatewiseTestingDetails.xlsx")
df.drop(['Negative'], axis=1,inplace=True)
df.head(20)
# Out:
#          Date           State  TotalSamples  Positive
# 0  2020-04-17  AndamanNicobar          1403      12.0
# 1  2020-04-24  AndamanNicobar          2679      27.0
# 2  2020-04-27  AndamanNicobar          2848      33.0
# 3  2020-05-01  AndamanNicobar          3754      33.0
# 4  2020-05-16  AndamanNicobar          6677      33.0
# 5  2020-05-19  AndamanNicobar          6965      33.0
# 6  2020-05-20  AndamanNicobar          7082      33.0
# 7  2020-05-21  AndamanNicobar          7167      33.0
# 8  2020-05-22  AndamanNicobar          7263      33.0
# 9  2020-05-23  AndamanNicobar          7327      33.0
# 10 2020-05-24  AndamanNicobar          7327      33.0
# 11 2020-05-25  AndamanNicobar          7363      33.0
# 12 2020-05-26  AndamanNicobar          7448      33.0
# 13 2020-05-27  AndamanNicobar          7499      33.0
# 14 2020-05-28  AndamanNicobar          7519      33.0
# 15 2020-05-29  AndamanNicobar          7567      33.0
# 16 2020-05-30  AndamanNicobar          7567      33.0
# 17 2020-05-31  AndamanNicobar          7706      33.0
# 18 2020-06-01  AndamanNicobar          7805      33.0
# 19 2020-06-02  AndamanNicobar          8086      33.0

# %% [markdown]
# **Checking for the datatypes is always a good habbit**

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# State                   object
# TotalSamples             int64
# Positive               float64
# dtype: object

# %% [markdown]
# * Calculate Negative Casses*

# %%
df['Negative'] = df['TotalSamples'] - df['Positive']
df.head(20)
# Out:
#          Date           State  TotalSamples  Positive  Negative
# 0  2020-04-17  AndamanNicobar          1403      12.0    1391.0
# 1  2020-04-24  AndamanNicobar          2679      27.0    2652.0
# 2  2020-04-27  AndamanNicobar          2848      33.0    2815.0
# 3  2020-05-01  AndamanNicobar          3754      33.0    3721.0
# 4  2020-05-16  AndamanNicobar          6677      33.0    6644.0
# 5  2020-05-19  AndamanNicobar          6965      33.0    6932.0
# 6  2020-05-20  AndamanNicobar          7082      33.0    7049.0
# 7  2020-05-21  AndamanNicobar          7167      33.0    7134.0
# 8  2020-05-22  AndamanNicobar          7263      33.0    7230.0
# 9  2020-05-23  AndamanNicobar          7327      33.0    7294.0
# 10 2020-05-24  AndamanNicobar          7327      33.0    7294.0
# 11 2020-05-25  AndamanNicobar          7363      33.0    7330.0
# 12 2020-05-26  AndamanNicobar          7448      33.0    7415.0
# 13 2020-05-27  AndamanNicobar          7499      33.0    7466.0
# 14 2020-05-28  AndamanNicobar          7519      33.0    7486.0
# 15 2020-05-29  AndamanNicobar          7567      33.0    7534.0
# 16 2020-05-30  AndamanNicobar          7567      33.0    7534.0
# 17 2020-05-31  AndamanNicobar          7706      33.0    7673.0
# 18 2020-06-01  AndamanNicobar          7805      33.0    7772.0
# 19 2020-06-02  AndamanNicobar          8086      33.0    8053.0

# %%
df['Positive'] = df['Positive'].replace(np.nan, 0)
df['Negative'] = df['Negative'].replace(np.nan, 0)
df.head(20)
# Out:
#          Date           State  TotalSamples  Positive  Negative
# 0  2020-04-17  AndamanNicobar          1403      12.0    1391.0
# 1  2020-04-24  AndamanNicobar          2679      27.0    2652.0
# 2  2020-04-27  AndamanNicobar          2848      33.0    2815.0
# 3  2020-05-01  AndamanNicobar          3754      33.0    3721.0
# 4  2020-05-16  AndamanNicobar          6677      33.0    6644.0
# 5  2020-05-19  AndamanNicobar          6965      33.0    6932.0
# 6  2020-05-20  AndamanNicobar          7082      33.0    7049.0
# 7  2020-05-21  AndamanNicobar          7167      33.0    7134.0
# 8  2020-05-22  AndamanNicobar          7263      33.0    7230.0
# 9  2020-05-23  AndamanNicobar          7327      33.0    7294.0
# 10 2020-05-24  AndamanNicobar          7327      33.0    7294.0
# 11 2020-05-25  AndamanNicobar          7363      33.0    7330.0
# 12 2020-05-26  AndamanNicobar          7448      33.0    7415.0
# 13 2020-05-27  AndamanNicobar          7499      33.0    7466.0
# 14 2020-05-28  AndamanNicobar          7519      33.0    7486.0
# 15 2020-05-29  AndamanNicobar          7567      33.0    7534.0
# 16 2020-05-30  AndamanNicobar          7567      33.0    7534.0
# 17 2020-05-31  AndamanNicobar          7706      33.0    7673.0
# 18 2020-06-01  AndamanNicobar          7805      33.0    7772.0
# 19 2020-06-02  AndamanNicobar          8086      33.0    8053.0

# %% [markdown]
# **Here sorting the data for Positive,Negative and Total Samples capture per states **

# %%
total_statewise_sample_captured= df.groupby("State")["TotalSamples"].sum().sort_values(ascending=False).to_frame()
total_statewise_sample_captured
# Out:
#                                           TotalSamples
# State
# Tamil Nadu                                    61613302
# Maharashtra                                   52912968
# A.P                                           45578912
# Rajasthan                                     44169834
# Uttar Pradesh                                 40021095
# Karnataka                                     32494451
# Delhi                                         26965515
# West Bengal                                   23365071
# Gujarat                                       21463941
# Madhya Pradesh                                19825229
# Jammu and Kashmir                             18311310
# Assam                                         15557718
# Odisha                                        14615930
# Haryana                                       14122281
# Punjab                                        13946471
# Kerala                                        12469623
# Bihar                                         10980012
# Chhattisgarh                                   7870895
# Jharkhand                                      7306254
# Himachal Pradesh                               3969732
# Telangana                                      3578136
# Uttarakhand                                    3503855
# Tripura                                        3198785
# Goa                                            3025061
# Dadra and Nagar Haveli and Daman and Diu       1312172
# Manipur                                        1290369
# Arunachal Pradesh                              1094088
# Puducherry                                      950569
# Meghalaya                                       833568
# AndamanNicobar                                  747388
# Nagaland                                        707173
# Ladakh                                          553148
# Mizoram                                         480956
# Chandigarh                                      441726
# Sikkim                                          436339

# %%
total_statewise_positive = df.groupby("State")["Positive"].sum().sort_values(ascending=False).to_frame()
total_statewise_positive
# Out:
#                                            Positive
# State
# Maharashtra                               8781694.0
# Tamil Nadu                                4213788.0
# Delhi                                     3738984.0
# Gujarat                                   1783762.0
# Uttar Pradesh                             1188620.0
# Rajasthan                                  983331.0
# West Bengal                                903599.0
# Karnataka                                  849365.0
# Madhya Pradesh                             823178.0
# A.P                                        766914.0
# Telangana                                  662436.0
# Haryana                                    612843.0
# Bihar                                      522905.0
# Jammu and Kashmir                          367524.0
# Odisha                                     350447.0
# Assam                                      346958.0
# Punjab                                     293110.0
# Kerala                                     234577.0
# Uttarakhand                                122629.0
# Chhattisgarh                               120388.0
# Jharkhand                                  119479.0
# Tripura                                     67399.0
# Goa                                         57443.0
# Himachal Pradesh                            42349.0
# Puducherry                                  32817.0
# Ladakh                                      28865.0
# Manipur                                     28468.0
# Chandigarh                                  26805.0
# Nagaland                                    19486.0
# Arunachal Pradesh                            9007.0
# Dadra and Nagar Haveli and Daman and Diu     8361.0
# Mizoram                                      6782.0
# Meghalaya                                    4704.0
# AndamanNicobar                               4327.0
# Sikkim                                       3717.0

# %%
total_statewise_negative = df.groupby("State")["Negative"].sum().sort_values(ascending=False).to_frame()
total_statewise_negative
# Out:
#                                             Negative
# State
# Tamil Nadu                                57399514.0
# A.P                                       44811998.0
# Maharashtra                               44115266.0
# Rajasthan                                 43186503.0
# Uttar Pradesh                             37452941.0
# Karnataka                                 31645086.0
# Delhi                                     23223910.0
# West Bengal                               22435092.0
# Gujarat                                   19680179.0
# Madhya Pradesh                            19002051.0
# Jammu and Kashmir                         17943786.0
# Assam                                     15210760.0
# Odisha                                    14265483.0
# Punjab                                    13653361.0
# Haryana                                   13509438.0
# Kerala                                    12235046.0
# Bihar                                     10457107.0
# Chhattisgarh                               7750507.0
# Jharkhand                                  7186775.0
# Himachal Pradesh                           3927383.0
# Uttarakhand                                3381226.0
# Tripura                                    3131386.0
# Goa                                        2967618.0
# Telangana                                  2915700.0
# Dadra and Nagar Haveli and Daman and Diu   1303811.0
# Manipur                                    1261901.0
# Arunachal Pradesh                          1085081.0
# Puducherry                                  917752.0
# Meghalaya                                   828864.0
# AndamanNicobar                              743061.0
# Nagaland                                    687687.0
# Ladakh                                      524283.0
# Mizoram                                     474174.0
# Sikkim                                      419100.0
# Chandigarh                                  414921.0

# %%
plt.pyplot.figure(figsize=(20,10))
x = df['TotalSamples']
y = df['State']
plt.pyplot.scatter(x,y)

# %%
plt.pyplot.figure(figsize=(20,10))
x = df['TotalSamples']
y = df['Positive']
plt.pyplot.scatter(x,y)
plt.pyplot.title("A Plot Between Total Samples and Positive Casses")
plt.pyplot.ylabel("Total Samples")
plt.pyplot.xlabel("Positive")
# Out:
# Text(0.5, 0, 'Positive')

# %%
plt.pyplot.figure(figsize=(20,10))
y = df['TotalSamples']
x = df['Negative']
plt.pyplot.scatter(x,y)
plt.pyplot.title("A Plot Between Total Samples and Negative Casses")
plt.pyplot.ylabel("Total Samples")
plt.pyplot.xlabel("Negative")
# Out:
# Text(0.5, 0, 'Negative')

# %%
plt.pyplot.figure(figsize=(20,10))
x = df['Positive']
y = df['Negative']
plt.pyplot.scatter(x,y)
plt.pyplot.title("A Plot Between Positive and Negative Casses")
plt.pyplot.xlabel("Positive")
plt.pyplot.ylabel("Negative")
# Out:
# Text(0, 0.5, 'Negative')

# %%
import seaborn as sea
sea.regplot(x= "Positive",y="Negative", data = df)
plt.pyplot.ylim(0)
# Out:
# (0.0, 2352268.4872495253)

# %%
sea.regplot(x= "TotalSamples",y="Negative", data = df)
plt.pyplot.ylim(0)
# Out:
# (0.0, 1838751.3547504423)

# %%
sea.regplot(x= "TotalSamples",y="Positive", data = df)
plt.pyplot.ylim(0)
# Out:
# (0.0, 321018.886442806)

# %% [markdown]
# **Now I am trying to find out if there ia any relation between Total sample and Positive and Negative **
# 1. I am going to use Pearson Corelation

# %%
pearson_coefficeint = df.corr(method='pearson')
pearson_coefficeint
# Out:
#               TotalSamples  Positive  Negative
# TotalSamples      1.000000  0.737082  0.992761
# Positive          0.737082  1.000000  0.688517
# Negative          0.992761  0.688517  1.000000

# %%
#plt.pyplot.figure(figsize=(5,5))

sea.heatmap(pearson_coefficeint, cmap='RdBu_r',annot=True)

# %% [markdown]
# ****My Data Visualization says that there is a strong co-relation between Negative and Total Samples Taken******
#
# **So my first Prediction will be to predict if total samples taken can predict the negative values**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x = df[['Positive','Negative']]
y = df['TotalSamples']

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2)
#plt.pyplot.scatter(x_train,y_train,label="Training Data")

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (2561, 2) (641, 2) (2561,) (641,)

# %%
x_train.head(20)
# Out:
#       Positive  Negative
# 2063      42.0    2454.0
# 936     9591.0  115117.0
# 1591    4311.0  220426.0
# 3179   15648.0  423610.0
# 1050    1213.0   98774.0
# 41        56.0   13938.0
# 3076    2725.0   59775.0
# 1544     534.0   43114.0
# 791    94695.0  502000.0
# 289      616.0   72038.0
# 516      446.0    7346.0
# 732     5104.0   62748.0
# 1426     614.0   74284.0
# 881     1198.0   61747.0
# 1617      22.0    2223.0
# 1189    1046.0   85973.0
# 1267    4730.0  249329.0
# 1607    9554.0  444162.0
# 2846     423.0   27937.0
# 192        2.0    3347.0

# %%
y_train.head(20)
# Out:
# 2063      2496
# 936     124708
# 1591    224737
# 3179    439258
# 1050     99987
# 41       13994
# 3076     62500
# 1544     43648
# 791     596695
# 289      72654
# 516       7792
# 732      67852
# 1426     74898
# 881      62945
# 1617      2245
# 1189     87019
# 1267    254059
# 1607    453716
# 2846     28360
# 192       3349
# Name: TotalSamples, dtype: int64

# %%
x_test.head(20)
# Out:
#       Positive  Negative
# 566       66.0   31275.0
# 2718   15512.0  381828.0
# 615     3305.0  182094.0
# 1145     152.0   22489.0
# 1096   19934.0  332409.0
# 621     4081.0  205783.0
# 2196     896.0   26031.0
# 1904     172.0   16856.0
# 2902     805.0   20579.0
# 2086     160.0   13771.0
# 2809   42496.0  195321.0
# 1224     614.0   19132.0
# 379     2344.0   58876.0
# 2479    5568.0  296262.0
# 2529    3579.0  148666.0
# 1910     490.0   25968.0
# 838       20.0    7991.0
# 669       14.0   13653.0
# 2635      12.0    6149.0
# 1959      20.0    6665.0

# %%
y_test.head(20)
# Out:
# 566      31341
# 2718    397340
# 615     185399
# 1145     22641
# 1096    352343
# 621     209864
# 2196     26927
# 1904     17028
# 2902     21384
# 2086     13931
# 2809    237817
# 1224     19746
# 379      61220
# 2479    301830
# 2529    152245
# 1910     26458
# 838       8011
# 669      13667
# 2635      6161
# 1959      6685
# Name: TotalSamples, dtype: int64

# %%
LR=LinearRegression()
LR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
LR.predict(x_test)
# Out:
# array([3.20768036e+04, 3.97508747e+05, 1.85876189e+05, 2.33930504e+04,
#        3.52620067e+05, 2.10301718e+05, 2.76758492e+04, 1.77903158e+04,
#        2.21423101e+04, 1.46988390e+04, 2.38438821e+05, 2.05061036e+04,
#        6.19157223e+04, 3.02110609e+05, 1.52783775e+05, 2.72052171e+04,
#        8.78868195e+03, 1.44344244e+04, 6.94197620e+03, 7.46507815e+03,
#        1.40797637e+03, 2.10869558e+03, 4.74155457e+05, 4.84278946e+03,
#        1.42943498e+04, 6.24547574e+03, 1.44901117e+04, 3.58718341e+05,
#        2.37074148e+04, 2.77057077e+03, 1.40399374e+04, 5.81448790e+05,
#        2.91054642e+04, 6.88595867e+03, 8.58313361e+03, 1.49418836e+05,
#        1.09155172e+05, 4.81448252e+05, 1.65548546e+03, 9.17528930e+04,
#        3.66752206e+04, 2.76012791e+05, 4.59172513e+05, 1.35221672e+04,
#        2.17161227e+03, 2.29306312e+05, 6.01397834e+04, 3.40109513e+04,
#        1.21677058e+06, 3.48412881e+05, 1.14343473e+04, 1.05311619e+06,
#        5.83056235e+05, 4.53945412e+03, 4.38938556e+05, 9.33788081e+03,
#        3.07238024e+05, 1.38556565e+04, 1.72909750e+04, 1.84914059e+05,
#        2.47566439e+05, 2.61291835e+04, 1.52791639e+06, 5.72822735e+04,
#        1.20337829e+05, 1.76589255e+05, 1.18160556e+05, 8.59894459e+04,
#        1.15781605e+05, 3.49365766e+05, 1.16317308e+04, 1.79122748e+03,
#        4.20493734e+03, 1.09382738e+04, 7.96248359e+03, 1.22925098e+03,
#        1.30999233e+05, 3.84572614e+05, 6.41987930e+03, 1.98577251e+05,
#        9.61281504e+04, 2.00004524e+03, 1.20139794e+06, 3.89356072e+05,
#        1.25756583e+04, 1.27299243e+05, 5.00157447e+04, 3.35081368e+05,
